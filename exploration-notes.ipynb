# %% [markdown]
# # Data Exploration
#
# This our first `Sherlock Holmesin'™` aka, our first examination of the data:
# 1. Establish Hypotheses
# 1. Discover patterns
# 1. Detect anomalies/outliers
# 1. Calculate summary statistics
# 1. Graph data to visually identify drivers
# > If a graph make you form a question, setup a __hypothesis test__ to test it!
# 1. Test Hypotheses
# - T-tests
# - Correlation Tests
# - Chi2 Tests
#
#
# In data exploration, a data scientist looks at the following interactions:
# - Continuous v. Continuous Attributes
# - Continuous v. Categorical Attributes
# - Discrete v. Continuous Attributes
# - Discrete v. Categorical Attributes
# - Target v. (Continuous, Discrete, and Categorical/Ordinal Attributes)
#
# ## Exploration Workflow
# ---
# 1. Formulate and write/type your hypotheses
#     - Make sure they answer/address your clients questions.
#     - Refine your hypothesis
#     - Know which statistical test(s) you'll need to perform.
#     - What drives the target variable?
#     - Which features drive the target variable?
# 1. Document your findings from each data visualizations
#     - Make sure they answer/address your clients questions.
# 1. Document the results of each hypothesis test
#     - Ask a fellow practitioner to review/talk through each test.
# 1. Document and explicitly state which attributes drive the outcome
#     - Explain the relationships between all attributes.
# 1. Summarize key findings
#     - Be brief: Answer the questions.
#     - Everything not in the `summary` section should be documented above the summary section.
#
# ### Data Visualization Workflow
# Plot the distributions!
# Check shape of each distribution: normal, skewed, bimodal
#
# 1. Plot each attribute
# 1. Plot each subgroup against the population

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.method.value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
sns.pairplot(df);

# %%
mask = np.zeros_like(df.corr())
mask[np.triu_indices_from(mask)] = True
mask

with sns.axes_style("white"):

    f, ax = plt.subplots(figsize=(12, 8))
    ax = sns.heatmap(df.corr(),
                     cmap='coolwarm',
                     mask=mask,
                     square=True,
                     annot=True);

# %%
sns.scatterplot(x=df.distance, y=df.mass, data=df);

# %%
# for attribute in df.columns.values:
#     for continuous in df.select_dtypes(exclude='O').columns.values:
#         sns.scatterplot(data=df,
#                         x=df[attribute],
#                         y=df[continuous]);

# %% [markdown]
# <div class="alert alert-block alert-info"> <strong>authors note</strong>:
# <br>
# Workflow
# <br>
# <br>
# Questions to ask yourself:
#
# 1. What's the big picture?
# 1. What's the _actionable_ insight?
# 1. Does it add, takeaway, or deviate from the main questions I need to answer?
# 1. Was it worth creating this visualization?
# 1. Does/Should my audience GAF?
# > Oh yeah? WHY? Explain insights with clear, simple, plain English.
# Tell your audience/board of directors/Data Science team why you're
# allotting their irreplaceable time and limited attention to that
# specific piece of information.
# >
# >They should think:
# >
# > "That's smart/helpful/illuminating/interesting."
# >
# >   "WOW. I can't believe we didn't see/missed that/over looked that."
# >
# >   "That graph is beautiful/simple/readable/intelligible. My dog could read it."
# >
# >   "We can use this to turn our business around/reduce costs/worker
# >   fatigue/increase profits/... the drivers of the outcome YOUR client
# >   is trying to predict!`
# >
# >    <strong>Make sure your work reflects that</strong>.
#
#  They should be:
#     1. Fully engaged
#     2. Attentively listening
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"> <strong>authors note</strong>:
# <br>
# Feedback from presentations/speeches
# <br>
# <br>
# Go through the motions/get your reps in/practice delivering your project. Speak with confidence. If your audience isn't engaged, you need to practice.
#
# That's okay.
# <br>
# No one is born a great orator. A world famous, one day old, master orator does not exist. Read a book on communication/public speaking and deliberately/actively practice to solidify the teachings. Graft it TO YOUR NEURONS, INTO YOUR BEING.
# <br>
# <br>
# How?
# <br>
# Call your dad, mom, family member, friend. Talk to your barber/cashier/stranger/rubber ducky. Open your mouth, contract your diaphragm, flap your tongue, and speak. Eventually you will understand that chatting and speaking are essential to life. Speaking with genuine goodwill/curiosity/interest, CONNECTS YOU WITH THE PERSON. That's what communication is all about.
# <br>
# <br>
# Now.
# <br>
# If you "practiced" and your audience wasn't engaged, you:
# 1. Didn't practice as if you were actually presenting. As if they we're sitting in front of you. As if you really cared about them.
# 1. Spoke with the energy of a dead skunk.
#
#     "It's like serving a completely burnt meal for your family and saying: 'Bon Appetite!'"
#
#
# 1. You didn't know the layout of your presentation.
# 1. You knew the numbers but forgot the story.
# 1. You had too much information in your presentation and overloaded the audience.
# 1. You did not lead the audience through your presentation. You threw up some slides/jupyter notebook/etc. on a screen and non-verbally said to your audience:
#
#     "_You_ figure it out. _I_ did the analysis"
#
#     Example:
#     "Like giving a book to a child that doesn't know how to read yet and asking them to read it. They also need to provide a summary of each chapter, lessons learned, and how the information can be applied in their own life. They'll look you with piercing eyes and become angry. They'll throw the book down and storm out. - _This_ is how your audience feels like when you don't guide them."
# <br>
# 1. You knew the story but forgot to condense it.
# `secret_formula: plain_english = ELI5 + TL;DR`
#
# That being said.
# <br>
# The project is for __YOUR CLIENT__. You're their trusted advisor. Turnover the data for every insight like it's the only thing you'll be remembered for. Smell the data, feel the data, see the data, taste the data, hear the data = Bring the data to life. Demonstrate stewardship, craftsmanship and human dignity!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"> <strong>authors note</strong>:
# <br>
# Quotes
# <br>
# <br>
# I'm working on crafting, developing, practicing, refining, and incorporating a world class Data Science workflow. These came to mind as I thought about workflow/project planning:
# <br>
# <br>
#
# `Start with a map, the thing you write down. Otherwise, you start by throwing sand in your own eyes while shouting, "I can do this!". You take the first steps to do the thing you can't see. You grope desperately for a guide post to keep you moving forward. Your enthusiasm left long ago and you're off course. As a final resort, you stare directly into the Sun hoping that the thing will be accomplished without YOU doing it.`
# `The map is your eyes. See.`
# <br>
# <strong>`Christopher Ortiz, 2020`</strong>
# <br>
# <br>
#
# `Project/Idea Synergism: A useful idea not written down, developed, and acted upon went through your mind in vain.`
# <br>
# <strong>`Christopher Ortiz, 2020`</strong>
# <br>
# <br>
#
# `Poor preparation is the worst non-verbal disrespect a person can demonstrate toward another. You take your credibility and thoroughly wipe your bum with it. You implicitly tell the person(s) who was/were in your stewardship that you didn't really care. You didn't care about:`<strong>`them`</strong>
# `You're a trusted advisor. Think like it. Act like it.`
# <br>
# <strong>`Christopher Ortiz, 2020`</strong>
# <br>
# <br>
# `Enthusiasm without knowledge is no good; haste makes mistakes.`
# <br>
# <strong>`Proverbs 19:2`</strong></div>
